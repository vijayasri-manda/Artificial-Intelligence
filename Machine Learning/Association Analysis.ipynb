# %%
# Install necessary libraries (if not already installed)
# pip install mlxtend pandas

import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# Step 1: Create a sample dataset
dataset = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Milk', 'Butter'],
    ['Bread', 'Butter']
]

# Step 2: Convert dataset into a one-hot encoded DataFrame
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

print("Dataset:")
print(df)

# Step 3: Find Frequent Itemsets
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
print("\nFrequent Itemsets:")
print(frequent_itemsets)

# Step 4: Generate Association Rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Dataset:
#    Bread  Butter   Milk
# 0   True    True   True
# 1   True    True  False
# 2   True   False   True
# 3  False    True   True
# 4   True    True  False
#
# Frequent Itemsets:
#    support         itemsets
# 0      0.8          (Bread)
# 1      0.8         (Butter)
# 2      0.6           (Milk)
# 3      0.6  (Butter, Bread)
# 4      0.4    (Milk, Bread)
# 5      0.4   (Milk, Butter)
#
# Association Rules:
#   antecedents consequents  support  confidence      lift
# 0    (Butter)     (Bread)      0.6    0.750000  0.937500
# 1     (Bread)    (Butter)      0.6    0.750000  0.937500
# 2      (Milk)     (Bread)      0.4    0.666667  0.833333
# 3      (Milk)    (Butter)      0.4    0.666667  0.833333

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

dataset = [
    ['India', 'USA', 'Canada'],
    ['Germany', 'USA'],
    ['India', 'Canada'],
    ['India', 'Germany'],
    ['USA', 'Canada'],
    ['India', 'Canada', 'Germany'],
    ['Brazil', 'India', 'USA'],
]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

print("Dataset:")
print(df)

frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
print("\nFrequent Itemsets:")
print(frequent_itemsets)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Dataset:
#    Brazil  Canada  Germany  India    USA
# 0   False    True    False   True   True
# 1   False   False     True  False   True
# 2   False    True    False   True  False
# 3   False   False     True   True  False
# 4   False    True    False  False   True
# 5   False    True     True   True  False
# 6    True   False    False   True   True
#
# Frequent Itemsets:
#     support         itemsets
# 0  0.571429         (Canada)
# 1  0.428571        (Germany)
# 2  0.714286          (India)
# 3  0.571429            (USA)
# 4  0.428571  (Canada, India)
#
# Association Rules:
#   antecedents consequents   support  confidence  lift
# 0    (Canada)     (India)  0.428571        0.75  1.05
# 1     (India)    (Canada)  0.428571        0.60  1.05

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
dataset = [
    ['India', 'USA', 'Canada'],
    ['Germany', 'USA'],
    ['India', 'Canada'],
    ['India', 'Germany'],
    ['USA', 'Canada'],
    ['India', 'Canada', 'Germany'],
    ['Brazil', 'India', 'USA'],
]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

print("Dataset:")
print(df)

frequent_itemsets = apriori(df, min_support=0.7, use_colnames=True)
print("\nFrequent Itemsets:")
print(frequent_itemsets)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Dataset:
#    Brazil  Canada  Germany  India    USA
# 0   False    True    False   True   True
# 1   False   False     True  False   True
# 2   False    True    False   True  False
# 3   False   False     True   True  False
# 4   False    True    False  False   True
# 5   False    True     True   True  False
# 6    True   False    False   True   True
#
# Frequent Itemsets:
#     support itemsets
# 0  0.714286  (India)
#
# Association Rules:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
dataset = [
    ['India', 'USA', 'Canada'],
    ['Germany', 'USA'],
    ['India', 'Canada'],
    ['India', 'Germany'],
    ['USA', 'Canada'],
    ['India', 'Canada', 'Germany'],
    ['Brazil', 'India', 'USA'],
]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

print("Dataset:")
print(df)

frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)
print("\nFrequent Itemsets:")
print(frequent_itemsets)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Dataset:
#    Brazil  Canada  Germany  India    USA
# 0   False    True    False   True   True
# 1   False   False     True  False   True
# 2   False    True    False   True  False
# 3   False   False     True   True  False
# 4   False    True    False  False   True
# 5   False    True     True   True  False
# 6    True   False    False   True   True
#
# Frequent Itemsets:
#     support          itemsets
# 0  0.571429          (Canada)
# 1  0.428571         (Germany)
# 2  0.714286           (India)
# 3  0.571429             (USA)
# 4  0.428571   (Canada, India)
# 5  0.285714     (Canada, USA)
# 6  0.285714  (India, Germany)
# 7  0.285714      (USA, India)
#
# Association Rules:
#   antecedents consequents   support  confidence      lift
# 0    (Canada)     (India)  0.428571    0.750000  1.050000
# 1     (India)    (Canada)  0.428571    0.600000  1.050000
# 2   (Germany)     (India)  0.285714    0.666667  0.933333
